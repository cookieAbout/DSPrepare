# %%
""" """
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(1, 100)
# x = np.linspace(-10, -1)
sine = np.sin(x * np.pi / 180)
cosine = np.cos(x * np.pi / 180)
tang = sine / cosine
atan = np.atan(x)
log2 = np.log2(x)
hlf_log = np.emath.logn(0.5, x)  # логарифм по основанию 0.5
sqrt_x = np.sqrt(x)

plt.plot(x, hlf_log, linewidth=3)
plt.xlabel('time')
plt.ylabel('curve')
plt.grid(True)
plt.show()
